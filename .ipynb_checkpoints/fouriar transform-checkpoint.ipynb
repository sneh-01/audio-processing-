# %%
import librosa
import librosa.display
import scipy as sp
import IPython.display as ipd
import matplotlib.pyplot as plt
import numpy as np

# %%
a = "E:\\audio processing\\audio files\\ccae108d4b342e49bc2d56855c58-orig.WAV"
ipd.Audio(a)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
signal , sr = librosa.load(a)

# %%
plt.figure(figsize=(18,8))
librosa.display.waveshow(signal , sr=sr , alpha=0.5)

# %%
ft = sp.fft.fft(signal)
magnitude = np.absolute(ft)
frequency = np.linspace(0 , sr ,len(magnitude))

# %%
plt.figure(figsize=(18,8))
plt.plot(frequency[:5000], magnitude[:5000])
plt.xlabel("Freq")
plt.ylabel("magnitude")
plt.show()

# %%
len(signal)
# Out:
# 56520

# %%
# sampling rate or duratio of each sample 
d = 1 / sr
d
# Out:
# 4.5351473922902495e-05

# %%
d_523 = 1 / 523
d_523
# Out:
# 0.0019120458891013384

# %%
d_400_sample = 400 * d
d_400_sample
# Out:
# 0.018140589569160998

# %%
samples  = range(len(signal))
t = librosa.samples_to_time(samples , sr=sr)
plt.figure(figsize=(18,8))
plt.plot(t[10000:10400] , signal[10000:10400])
plt.xlabel("time")
plt.ylabel("amplitude")
plt.show()
